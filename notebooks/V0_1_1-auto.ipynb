# %%
# jupyter-notebook V0_1_1.ipynb --port 8888 --ip 192.168.1.5

import cv2
import os
import numpy as np
from collections import Counter
import itertools  
from collections import defaultdict
import time
import numba as nb
import copy
from os import listdir, mkdir
from os.path import isfile, isdir, join

from components_container import ComponentsContainer

# %matplotlib inline

# %%
    
@nb.jit()
def change_color_of_indices(markers, indices_to_change, color):
    for i in range(markers.shape[0]):
        for j in range(markers.shape[1]):
            if markers[i,j] in indices_to_change:
                markers[i,j] = color
    return markers

@nb.jit()
def edges_close(edge1x, edge1y, edge2x, edge2y, thr):
    thrs = thr ** 2
    for i in range(len(edge1x)):
        x1 = edge1x[i]
        y1 = edge1y[i]
        for j in range(len(edge2x)):
            x2 = edge2x[j]
            y2 = edge2y[j]
            delta1 = x1 - x2
            delta2 = y1 - y2
                       
            if (delta1 ** 2 + delta2**2) < thrs:
                return True, ((x1, y1), (x2, y2))
    return False, None


class ComponentsContainer():
    
    def __init__(self, binary, low):
        
        nbComponents, markers, stats, centroids = cv2.connectedComponentsWithStats(binary, connectivity=8)

        components_index = {}
        background_size = max(stats[:, -1])
        small_comp_indices = []
        for i in range(len(stats)):
            if low < stats[i, -1] < background_size:
                components_index[i] = Component(stats[i, -1], centroids[i], i)
            else:
                small_comp_indices.append(i)
        markers = change_color_of_indices(markers, small_comp_indices, 0)

        self.binary = binary
        self.markers = markers
        self.components_index = components_index
        self.nucleus_labs = list()
        self.axon_labs = list()

        self.add_edge_info_to_components()


    
    def add_edge_info_to_components(self):
        for i in range(1, self.markers.shape[0] - 1):
            for j in range(1, self.markers.shape[1] - 1):
                cur_lab = self.markers[i, j]
                if cur_lab in self.components_index.keys() and \
                        not cur_lab == \
                                self.markers[i, j + 1] == \
                                self.markers[i, j - 1] == \
                                self.markers[i + 1, j] == \
                                self.markers[i - 1, j]:
                    self.components_index[cur_lab].add_edge(np.array([i, j]))

    @nb.jit()
    def merge_components_closer_than(self, centroid_t, contour_t):
        pairs_to_merge = []
        for first, second in itertools.combinations(self.components_index.keys(), 2):
            close_flag, points = self.components_index.get(first).is_close(self.components_index.get(second),
                                                                           centroid_t, contour_t)
            if close_flag:
                pairs_to_merge.append((first, second, points))
                
        starttime = time.time()
        for tm in pairs_to_merge:
            self._merge_two_components(*tm)


    def split_nucl_axon(self, threshold):
        self.nucleus_labs = list()
        self.axon_labs = list()
        
        for lab in self.components_index.keys():
            if not self.components_index.get(lab).label == lab:
                continue
            if self.components_index.get(lab).size > threshold:
                self.components_index[lab] = Nucleus.from_component(self.components_index[lab])
                self.nucleus_labs.append(lab)
            else:
                self.components_index[lab] = Axon.from_component(self.components_index[lab])
                self.axon_labs.append(lab)
        
    def group_axons_to_nucleus(self, centroid_t, contour_t):

        axons_with_nucl = 0
        for nucl_lab in self.nucleus_labs:
            nucl = self.components_index.get(nucl_lab)
            for axon_lab in self.axon_labs:
                axon = self.components_index.get(axon_lab)
                close, point = nucl.is_close(axon, centroid_t, contour_t)
                if (not axon.attached) and close:
                    nucl.axons.append(axon)
                    axon.attached = True
                    axons_with_nucl += 1


    def _merge_two_components(self, survivor_label, disappearing_label, joint_points):
        disappearing_label = self.get_correct_label(disappearing_label)
        survivor_label = self.get_correct_label(survivor_label)
        if survivor_label == disappearing_label:
            return

        self.components_index[survivor_label].size += self.components_index[disappearing_label].size
        self.components_index[survivor_label].edge.extend(self.components_index[disappearing_label].edge)
        self.components_index[disappearing_label].label = self.components_index[survivor_label].label

        self.markers[self.markers == disappearing_label] = survivor_label

        cv2.line(self.markers, (joint_points[0][1], joint_points[0][0]),
                 (joint_points[1][1], joint_points[1][0]), survivor_label, lineType=4,
                 thickness=2)

    def get_correct_label(self, label):
        if label == self.components_index.get(label).label:
            return label
        else:
            return self.get_correct_label(self.components_index.get(label).label)



class Component:
    def __init__(self, size, centroid, label):
        self.size = size
        self.centroid = centroid
        self.label = label
        self.edge = []

    @classmethod
    def from_component(cls, component):
        return cls(component.size, component.centroid, component.label, component.edge)

    def add_edge(self, point):
        self.edge.append(point)

    def is_close(self, second_comp, centroid_t, contour_t):
        if self.is_centroid_close(second_comp, centroid_t):
            return self.is_contour_close(second_comp, contour_t)
        else:
            return False, None

    def is_centroid_close(self, second_comp, thr):
        return np.linalg.norm(self.centroid - second_comp.centroid) < thr

    def is_contour_close(self, second_comp, thr):
        
        e1 = np.array(self.edge)
        e2 = np.array(second_comp.edge)
        return edges_close(e1[:,0],e1[:,1], e2[:,0],e2[:,1], thr)
    
    def is_nucleus(self):
        return False


class Nucleus(Component):
    def __str__(self):
        
        return "nucl size: {}, border_len: {}, axon_count: {}".format(self.size, len(self.edge), len(self.axons))
    def __init__(self, size, centroid, label, edge, axons=list()):
        super().__init__(size, centroid, label)
        if axons:
            self.axons = axons
        else:
            self.axons = list()
            
        self.edge = edge


    def is_nucleus(self):
        return True


class Axon(Component):
    def __str__(self):
        
        return "axon -- size: {}, border_len: {}".format(self.size, len(self.edge))
    def __init__(self, size, centroid, label, edge, attached=False):
        super().__init__(size, centroid, label)
        self.attached = attached
        self.edge = edge

# %%
# filter all noise using minimum size threshold
BACKGROUND_INTENSITY_THRESHOLD = 20
MIN_AXON_SIZE = 20

# merging close components based on centroids and contour distance
PREMERGE_CENTROIDS_DISTANCE_T  = 200
PREMERGE_CONTOUR_DISTANCE_T = 15

#splitting nucleus and axons based on size
MIN_NUCLEUS_SIZE = 150

#grouping possible axons to nucleus
CENTROIDS_DISTANCE_T = 90
CONTOUR_DISTANCE_T = 25

LOADPATH = '../raw_pics'
SAVEPATH = '../info'
RECURSIVE = True

# %%
def mirror_dir_for_save(loadpath):
    try:
        mkdir(loadpath.replace(LOADPATH, SAVEPATH))
    except(OSError):
        pass
    
def process_dir(loadpath):
    mirror_dir_for_save(loadpath)
    object_names_in_folder = listdir(loadpath)
    print ("start processing folder {} pics: {}".format(loadpath, str(len(object_names_in_folder))))
    for f in object_names_in_folder:
        local_object = join(loadpath, f)

        if isfile(local_object) and f[0] != '.':
            process_pic(join(loadpath, f))
            continue

        if RECURSIVE and isdir(join(loadpath, f)):
            process_dir(join(loadpath, f))
            continue

def process_pic(path):
    starttime = time.time()
    print("processing pic {} ...".format(path), end = "")
    img = cv2.imread(path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, binary = cv2.threshold(gray, BACKGROUND_INTENSITY_THRESHOLD, 400, cv2.THRESH_BINARY)
    container = ComponentsContainer(binary, MIN_AXON_SIZE)
    container.merge_components_closer_than(PREMERGE_CENTROIDS_DISTANCE_T, PREMERGE_CONTOUR_DISTANCE_T)
    container.split_nucl_axon(MIN_NUCLEUS_SIZE)
    container.group_axons_to_nucleus(CENTROIDS_DISTANCE_T, CONTOUR_DISTANCE_T)
    with open(path.replace(LOADPATH, SAVEPATH).replace(".bmp", ".txt"), "w") as f:
        write_info_from_container(container, f)
        
    print('done in {} sec.'.format(time.time() - starttime))


def write_info_from_container(container, f):
    labs = sorted(container.nucleus_labs, key = lambda x: -container.components_index.get(x).size)
    f.write("#, Size, Perimeter, P/S\n")
    i = 0
    for nucl_lab in labs:
        i +=1
        nucl = container.components_index.get(nucl_lab)
        f.write("{:2}, {:4}, {:4}, {:.3}\n".format(i, nucl.size, len(nucl.edge), len(nucl.edge)/nucl.size))

# %%
process_dir(LOADPATH)
# Out:
# start processing folder ../raw_pics pics: 6
# start processing folder ../raw_pics/.ipynb_checkpoints pics: 0
# start processing folder ../raw_pics/day4 pics: 3
# start processing folder ../raw_pics/day4/day4 pics: 5
# start processing folder ../raw_pics/day4/day4/c4 pics: 7
# processing pic ../raw_pics/day4/day4/c4/c4-ba-cortex_1z.bmp ...done in 10.456705093383789 sec.
# processing pic ../raw_pics/day4/day4/c4/c4-ba-cortex_2z.bmp ...done in 7.250401020050049 sec.
# processing pic ../raw_pics/day4/day4/c4/c4-ba-cortex_3z.bmp ...done in 12.128487825393677 sec.
# processing pic ../raw_pics/day4/day4/c4/c4-ba-cortex_4z.bmp ...done in 9.333531856536865 sec.
# processing pic ../raw_pics/day4/day4/c4/c4-ba-cortex_left_1z.bmp ...done in 9.889332294464111 sec.
# processing pic ../raw_pics/day4/day4/c4/c4-ba-cortex_left_2z.bmp ...done in 16.793180227279663 sec.
# processing pic ../raw_pics/day4/day4/c4/c4-ba-cortex_left_3z.bmp ...done in 9.824698209762573 sec.
# start processing folder ../raw_pics/day4/day4/c4-06-73 pics: 8
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_ba-cortex_1z.bmp ...done in 6.702815055847168 sec.
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_ba-cortex_2z.bmp ...done in 13.237953901290894 sec.
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_ba-cortex_3z.bmp ...done in 41.93050217628479 sec.
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_ba-cortex_4z.bmp ...done in 28.819695234298706 sec.
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_iba_left_cortex_1z.bmp ...done in 28.556944131851196 sec.
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_iba_left_cortex_2z.bmp ...done in 27.04343605041504 sec.
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_iba_left_cortex_3z.bmp ...done in 9.385626792907715 sec.
# processing pic ../raw_pics/day4/day4/c4-06-73/c4-_06_73_iba_left_cortex_4z.bmp ...done in 5.0228660106658936 sec.
# start processing folder ../raw_pics/day4/day4/k4 pics: 6
# processing pic ../raw_pics/day4/day4/k4/k4-ba-cortex_1z.bmp ...done in 7.144515037536621 sec.
# processing pic ../raw_pics/day4/day4/k4/k4-ba-cortex_2z.bmp ...done in 14.763507843017578 sec.
# processing pic ../raw_pics/day4/day4/k4/k4-ba-cortex_3z.bmp ...done in 13.639169931411743 sec.
# processing pic ../raw_pics/day4/day4/k4/k4-ba-cortex_left_1z.bmp ...done in 6.226074934005737 sec.
# processing pic ../raw_pics/day4/day4/k4/k4-ba-cortex_left_2z.bmp ...done in 7.564300060272217 sec.
# processing pic ../raw_pics/day4/day4/k4/k4-ba-cortex_left_3z.bmp ...done in 17.569228172302246 sec.
# start processing folder ../raw_pics/day4/day4/k4-1-19 pics: 8
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_1z.bmp ...done in 253.79346299171448 sec.
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_2z.bmp ...done in 15.705504894256592 sec.
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_3z.bmp ...done in 21.93700385093689 sec.
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_4z.bmp ...done in 18.127324104309082 sec.
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_left_1z.bmp ...done in 18.012035131454468 sec.
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_left_2z.bmp ...done in 15.939463376998901 sec.
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_left_3z.bmp ...done in 12.143306016921997 sec.
# processing pic ../raw_pics/day4/day4/k4-1-19/k4_01_19_-ba-cortex_left_4z.bmp ...done in 11.964484691619873 sec.
# start processing folder ../raw_pics/day4/int pics: 3
# start processing folder ../raw_pics/day4/int/36 pics: 13
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex-_left_obz-d.bmp ...done in 9.10551404953003 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex-_left_obz-p.bmp ...done in 18.68503713607788 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex-obz_d.bmp ...done in 0.948401927947998 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex-obz_p.bmp ...done in 5.728880882263184 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_1z.bmp ...done in 47.01627993583679 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_2z.bmp ...done in 27.242300271987915 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_3z.bmp ...done in 50.625954151153564 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_4z.bmp ...done in 30.70478320121765 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_5z.bmp ...done in 23.81588625907898 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_left_1z.bmp ...done in 186.3400137424469 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_left_2z.bmp ...done in 63.236624240875244 sec.
# processing pic ../raw_pics/day4/int/36/36_int_iba_cortex_left_3z.bmp ...done in 46.37737321853638 sec.
# start processing folder ../raw_pics/day4/int/74 pics: 12
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex_01z.bmp ...done in 12.233068943023682 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex_02z.bmp ...done in 22.271376132965088 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex_03z.bmp ...done in 30.212358951568604 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex_04z.bmp ...done in 11.135084629058838 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex__left_01z.bmp ...done in 34.227981090545654 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex__left_02z.bmp ...done in 17.253498077392578 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex__left_03z.bmp ...done in 21.086176872253418 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_cortex__left_04z.bmp ...done in 21.488812923431396 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_obzor_cortex.bmp ...done in 40.72397494316101 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_obzor_cortex_p.bmp ...done in 22.038701057434082 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_obzor_left_cortex.bmp ...done in 10.272681951522827 sec.
# processing pic ../raw_pics/day4/int/74/int74_iba_obzor_left_cortex_p.bmp ...done in 2.677198886871338 sec.
# start processing folder ../raw_pics/exp pics: 7
# start processing folder ../raw_pics/exp/36int pics: 9
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex-_left_1z.bmp ...done in 28.182528018951416 sec.
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex-_left_2z.bmp ...done in 65.0396318435669 sec.
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex-_left_3z.bmp ...done in 50.25875997543335 sec.
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex_1z.bmp ...done in 46.734987020492554 sec.
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex_2z.bmp ...done in 27.2026948928833 sec.
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex_3z.bmp ...done in 50.85345387458801 sec.
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex_4z.bmp ...done in 30.25949192047119 sec.
# processing pic ../raw_pics/exp/36int/36_int_iba_cortex_5z.bmp ...done in 23.638390064239502 sec.
# start processing folder ../raw_pics/exp/74int_net pics: 8
# processing pic ../raw_pics/exp/74int_net/int74_iba_cortex_01z.bmp ...done in 8.202431917190552 sec.
# processing pic ../raw_pics/exp/74int_net/int74_iba_cortex_02z.bmp ...done in 7.443596839904785 sec.
# processing pic ../raw_pics/exp/74int_net/int74_iba_cortex_03z.bmp ...done in 5.518263101577759 sec.
# processing pic ../raw_pics/exp/74int_net/int74_iba_cortex_04z.bmp ...done in 3.595170736312866 sec.
# processing pic ../raw_pics/exp/74int_net/int74_iba_left_cortex_01z.bmp ...done in 7.327418327331543 sec.
# processing pic ../raw_pics/exp/74int_net/int74_iba_left_cortex_02z.bmp ...done in 7.61104416847229 sec.
# processing pic ../raw_pics/exp/74int_net/int74_iba_left_cortex_03z.bmp ...done in 5.7169952392578125 sec.
# processing pic ../raw_pics/exp/74int_net/int74_iba_left_cortex_04z.bmp ...done in 4.711503982543945 sec.
# start processing folder ../raw_pics/exp/c36 pics: 9
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_left_z_01.bmp ...done in 51.09408187866211 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_left_z_02.bmp ...done in 28.286916255950928 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_left_z_03.bmp ...done in 12.830418109893799 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_left_z_04.bmp ...done in 10.140773057937622 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_left_z_05.bmp ...done in 15.287462949752808 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_z_01.bmp ...done in 320.5949990749359 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_z_02.bmp ...done in 63.62076497077942 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_z_03.bmp ...done in 28.494102001190186 sec.
# processing pic ../raw_pics/exp/c36/36-c10-iba-cortex_z_04.bmp ...done in 13.238755702972412 sec.
# start processing folder ../raw_pics/exp/c41net pics: 8
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_01z.bmp ...done in 1.0881199836730957 sec.
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_02z.bmp ...done in 1.307912826538086 sec.
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_03z.bmp ...done in 1.8220951557159424 sec.
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_04z.bmp ...done in 1.670248031616211 sec.
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_left_01z.bmp ...done in 0.6777112483978271 sec.
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_left_02z.bmp ...done in 0.6296930313110352 sec.
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_left_03z.bmp ...done in 0.6685407161712646 sec.
# processing pic ../raw_pics/exp/c41net/c10-41-iba-cortex_left_04z.bmp ...done in 0.7359929084777832 sec.
# start processing folder ../raw_pics/exp/k10net pics: 8
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_cortex_1z.bmp ...done in 3.322066068649292 sec.
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_cortex_2z.bmp ...done in 1.9938478469848633 sec.
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_cortex_3z.bmp ...done in 1.288379192352295 sec.
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_cortex_4z.bmp ...done in 0.7453548908233643 sec.
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_left_cortex_1z.bmp ...done in 1.5769720077514648 sec.
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_left_cortex_2z.bmp ...done in 0.8517041206359863 sec.
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_left_cortex_3z.bmp ...done in 0.7434930801391602 sec.
# processing pic ../raw_pics/exp/k10net/k10_10_iba_obzor_left_cortex_4z.bmp ...done in 0.7144300937652588 sec.
# start processing folder ../raw_pics/exp/k20 pics: 7
# processing pic ../raw_pics/exp/k20/20-k10-iba-cortex1 z.bmp ...done in 313.20205998420715 sec.
# processing pic ../raw_pics/exp/k20/20-k10-iba-cortex1_z_02.bmp ...done in 104.92116189002991 sec.
# processing pic ../raw_pics/exp/k20/20-k10-iba-cortex1_z_03.bmp ...done in 58.29526925086975 sec.
# processing pic ../raw_pics/exp/k20/20-k10-iba-cortex_left_z_01.bmp ...done in 44.57869100570679 sec.
# processing pic ../raw_pics/exp/k20/20-k10-iba-cortex_left_z_02.bmp ...done in 14.1701500415802 sec.
# processing pic ../raw_pics/exp/k20/20-k10-iba-cortex_left_z_03.bmp ...done in 19.99357795715332 sec.
# processing pic ../raw_pics/exp/k20/20-k10-iba-cortex_left_z_04.bmp ...done in 14.438570976257324 sec.
# processing pic ../raw_pics/iba_500_555_2.bmp ...done in 162.5390179157257 sec.
# start processing folder ../raw_pics/zen-1 pics: 7
# processing pic ../raw_pics/zen-1/c10-41-iba-cortex_03z.bmp ...done in 1.7525970935821533 sec.
# processing pic ../raw_pics/zen-1/c10-41-iba-cortex_03z_1.bmp ...done in 1.8016998767852783 sec.
# processing pic ../raw_pics/zen-1/c10-41-iba-cortex_03z_2.bmp ...done in 7.916723966598511 sec.
# processing pic ../raw_pics/zen-1/k10_10_iba_obzor_cortex_3z.bmp ...done in 1.3026130199432373 sec.
# processing pic ../raw_pics/zen-1/k10_10_iba_obzor_cortex_3z_1_1.bmp ...done in 1.3038761615753174 sec.
# processing pic ../raw_pics/zen-1/k10_10_iba_obzor_cortex_3z_1_3.bmp ...done in 7.821890115737915 sec.

# %%
# to do
# Write function to compute distance between contours. 

# more ideas:
# search for axons form axons
# implement contour filtering of axons
# add intensity related features
# Check if two centroids is closely contcted and merge them if needed.
